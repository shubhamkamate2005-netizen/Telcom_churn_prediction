# %% [markdown]
# # Telcom Churn predition data Analysis

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("churn_data.csv")
print("----------------First Five Samples-------------------------")
data.sample(5)
# Out:
# ----------------First Five Samples-------------------------
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4307  6899-PPEEA  Female              1      No         No      37
# 4856  8714-EUHJO  Female              0     Yes        Yes      31
# 5566  2302-OUZXB    Male              0     Yes         No      72
# 581   3627-FHKBK  Female              0      No         No       1
# 3333  4573-JKNAE    Male              0      No        Yes      12
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 4307          Yes           Yes     Fiber optic                   No  ...
# 4856          Yes           Yes     Fiber optic                   No  ...
# 5566          Yes           Yes             DSL                   No  ...
# 581           Yes            No     Fiber optic                  Yes  ...
# 3333          Yes            No              No  No internet service  ...
#
# ...

# %%
print("-------------------------last five rows----------------------")
data.tail()
# Out:
# -------------------------last five rows----------------------
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
# ...

# %%
print("------------how big your data----------------")
print(f"data of size:{data.shape}")
# Out:
# ------------how big your data----------------
# data of size:(7043, 21)

# %%
print("------------is there any null values----------------")
print(data.isnull().sum())
# Out:
# ------------is there any null values----------------
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
print("------------Mathematical info of the dataset---------------")
data.describe()
# Out:
# ------------Mathematical info of the dataset---------------
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
print("----------Senior citizen vs churn-------------")
print(data['SeniorCitizen'].value_counts())
sns.countplot(x=data['SeniorCitizen'],hue=data['Churn'],data=data)
# Out:
# ----------Senior citizen vs churn-------------
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64
# <Axes: xlabel='SeniorCitizen', ylabel='count'>

# %%
print("----------Dependents citizen vs churn-------------")
print(data['Dependents'].value_counts())
sns.countplot(x=data['Dependents'],hue=data['Churn'],data=data)
# Out:
# ----------Dependents citizen vs churn-------------
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64
# <Axes: xlabel='Dependents', ylabel='count'>

# %%
print("----------PhoneService citizen vs churn-------------")
print(data['PhoneService'].value_counts())
sns.countplot(x=data['PhoneService'],hue=data['Churn'],data=data)
# Out:
# ----------PhoneService citizen vs churn-------------
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64
# <Axes: xlabel='PhoneService', ylabel='count'>

# %%
print("----------Device protection vs churn-------------")
print(data['DeviceProtection'].value_counts())
sns.countplot(x=data['DeviceProtection'],hue=data['Churn'],data=data)
# Out:
# ----------Device protection vs churn-------------
# DeviceProtection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64
# <Axes: xlabel='DeviceProtection', ylabel='count'>

# %%
print("----------payment method vs churn-------------")
print(data['PaymentMethod'].value_counts())
sns.countplot(x=data['PaymentMethod'],hue=data['Churn'],data=data)
plt.tight_layout()
# Out:
# ----------payment method vs churn-------------
# PaymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
print("----------contract type vs churn-------------")
print(data['Contract'].value_counts())
sns.countplot(x=data['Contract'],hue=data['Churn'],data=data)
plt.tight_layout()
# Out:
# ----------contract type vs churn-------------
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
numeric_df = data.select_dtypes(include='number')
numeric_df.corr()
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges
# SeniorCitizen        1.000000  0.016567        0.220173
# tenure               0.016567  1.000000        0.247900
# MonthlyCharges       0.220173  0.247900        1.000000

# %%
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors='coerce')
data['tenure'] = pd.to_numeric(data['tenure'], errors='coerce')
data['MonthlyCharges'] = pd.to_numeric(data['MonthlyCharges'], errors='coerce')
data['SeniorCitizen'] = pd.to_numeric(data['SeniorCitizen'], errors='coerce')
data.dropna(subset=['TotalCharges'], inplace=True)
numeric_data = data.select_dtypes(include=['number'])
plt.figure(figsize=(8, 6))
corr = numeric_data.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1)
plt.title('Correlation Heatmap of All Numeric Features', fontsize=14)
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline

# %%
data_encoded = pd.get_dummies(data.drop('Churn', axis=1), drop_first=True)
X = data_encoded
y = data['Churn']
data_encoded.head()
data_encoded.columns
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'customerID_0003-MKNFE',
#        'customerID_0004-TLHLJ', 'customerID_0011-IGKFF',
#        'customerID_0013-EXCHZ', 'customerID_0013-MHZWF',
#        'customerID_0013-SMEOE', 'customerID_0014-BMAQU',
#        ...
#        'TotalCharges_995.35', 'TotalCharges_996.45', 'TotalCharges_996.85',
#        'TotalCharges_996.95', 'TotalCharges_997.65', 'TotalCharges_997.75',
#        'TotalCharges_998.1', 'TotalCharges_999.45', 'TotalCharges_999.8',
#        'TotalCharges_999.9'],
#       dtype='object', length=13601)

# %%
models = {
    "Logistic Regression": Pipeline([
        ('scaler', StandardScaler()),
        ('model', LogisticRegression(max_iter=3000, random_state=42))
    ]),
    
    "Random Forest": RandomForestClassifier(
        n_estimators=100, max_depth=8, random_state=42
    )
}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    cv_scores = cross_val_score(model, X, y, cv=5)
    
    print(f"\n--- {name} ---")
    print(f"Accuracy: {acc:.4f}")
    print(f"Cross Validation Score (mean): {cv_scores.mean():.4f}")
# Out:
# --- Logistic Regression ---
# Accuracy: 0.7637
# Cross Validation Score (mean): 0.7566
#
# --- Random Forest ---
# Accuracy: 0.7346
# Cross Validation Score (mean): 0.7346

# %%
data_encoded = pd.get_dummies(data, drop_first=True)

X = data_encoded.drop('Churn_Yes', axis=1)
y = data_encoded['Churn_Yes']


pipeline = Pipeline([
    ('scaler', StandardScaler()),   
    ('model', RandomForestClassifier(n_estimators=100, max_depth=8, random_state=42))
])

pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  RandomForestClassifier(max_depth=8, random_state=42))])

# %%
import joblib

joblib.dump(pipeline, "model.pkl")

print("Deployment-ready model saved!")
# Out:
# Deployment-ready model saved!
